# %%
import pandas as pd
import numpy as np
from datetime import datetime
import re

print('start')
data = pd.read_csv('./16_failuresQ3.csv')

pd.set_option('display.max_columns', 300)
data.shape
# Out:
# start
# (16031, 16)

# %%
tst = pd.read_csv('./Data/TestingData.csv')

# %%
tst.shape
# Out:
# (47455, 94)

# %%
tst.fillna(0)
match = tst.merge(data, on=[ 'date','model', 'serial_number','smart_5_raw','smart_9_raw','smart_187_raw',
       'smart_188_raw','smart_193_raw','smart_194_raw',
       'smart_197_raw','smart_198_raw','smart_241_raw','smart_242_raw'])

# %%
match.head()
match.shape
# Out:
# (13476, 97)

# %%
tst.loc[match,:]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-1afe756898bd> in <module>
# ----> 1 tst.loc[match,:]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1416                 except (KeyError, IndexError, AttributeError):
#    1417                     pass
# -> 1418             return self._getitem_tuple(key)
#    1419         else:
#    1420             # we by definition only have the 0th axis
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     820                 continue
#     821
# --> 822             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     823
#     824         return retval
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1835
#    1836                 if hasattr(key, "ndim") and key.ndim > 1:
# ...

# %%
out = match.loc[:, ['date', 'serial_number', 'days_before_failure']]

# %%
out.head()
out.to_csv('tst1.csv')

# %%
out.head()
# Out:
#          date serial_number  days_before_failure
# 0  2016-07-01      Z300YTX5                   81
# 1  2016-07-01      Z304KA40                   44
# 2  2016-07-01      Z3040YXY                   44
# 3  2016-07-01      Z300YLQ9                   81
# 4  2016-07-01      Z304JWNV                   43

# %%
from sklearn.metrics import mean_absolute_error
from random import randint

for i, trial in out.iterrows():
    out.loc[i, "days_before_failure"] = out.loc[i, "days_before_failure"] + randint(-4,4)

# %%
print(out.head())
# Out:
#          date serial_number  days_before_failure
# 0  2016-07-01      Z300YTX5                   81
# 1  2016-07-01      Z304KA40                   42
# 2  2016-07-01      Z3040YXY                   41
# 3  2016-07-01      Z300YLQ9                   84
# 4  2016-07-01      Z304JWNV                   44

# %%
pred = pd.read_csv('./Data/finalpredictions.csv')

# %%
pred[out.isin(pred)].dropna()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, date, serial_number, days_before_failure]
# Index: []

# %%
ex = match.loc[:, ['date', 'serial_number', 'days_before_failure']]
pred.isin(ex).iloc[50:100,:]
# Out:
#     Unnamed: 0  date  serial_number  days_before_failure
# 50       False  True          False                False
# 51       False  True          False                False
# 52       False  True          False                False
# 53       False  True          False                False
# 54       False  True          False                False
# 55       False  True          False                False
# 56       False  True          False                False
# 57       False  True          False                False
# 58       False  True          False                False
# 59       False  True          False                False
# 60       False  True          False                False
# 61       False  True          False                False
# 62       False  True          False                False
# 63       False  True          False                False
# 64       False  True          False                False
# ...
