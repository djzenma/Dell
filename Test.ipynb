# %%
from joblib import load
from sklearn.metrics import mean_absolute_error
import pandas as pd

data = pd.read_csv('./Data/TestingData.csv')
data.head()
# Out:
#          date   serial_number                 model  capacity_bytes  \
# 0  2016-07-01  PL2331LAGSTGLJ  HGST HMS5C4040ALE640   4000787030016
# 1  2016-07-01        Z300YTX5           ST4000DM000   4000787030016
# 2  2016-07-01        Z304KA40           ST4000DM000   4000787030016
# 3  2016-07-01        Z300CMBJ           ST4000DM000   4000787030016
# 4  2016-07-01        Z304JQ9T           ST4000DM000   4000787030016
#
#    smart_1_normalized  smart_1_raw  smart_2_normalized  smart_2_raw  \
# 0                  91      1507360               132.0        108.0
# 1                 119    231058072                 NaN          NaN
# 2                 117    132208752                 NaN          NaN
# 3                 117    143110952                 NaN          NaN
# 4                 118    174677504                 NaN          NaN
#
#    smart_3_normalized  smart_3_raw  ...  smart_250_normalized  smart_250_raw  \
# ...

# %%
from joblib import load
est = load('crossvalidation.joblib')
predictioncv = est.predict(data)
print(mean_absolute_error(predictioncv, y_test))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-66a673f6df23> in <module>
#       1 from joblib import load
# ----> 2 est = load('crossvalidation.joblib')
#       3 predictioncv = est.predict(data)
#       4 print(mean_absolute_error(predictioncv, y_test))
#
# ~\Anaconda3\lib\site-packages\joblib\numpy_pickle.py in load(filename, mmap_mode)
#     596                     return load_compatibility(fobj)
#     597
# --> 598                 obj = _unpickle(fobj, filename, mmap_mode)
#     599
#     600     return obj
#
# ~\Anaconda3\lib\site-packages\joblib\numpy_pickle.py in _unpickle(fobj, filename, mmap_mode)
#     524     obj = None
#     525     try:
# --> 526         obj = unpickler.load()
#     527         if unpickler.compat_mode:
#     528             warnings.warn("The file '%s' has been generated with a "
#
# ~\Anaconda3\lib\pickle.py in load(self)
# ...
